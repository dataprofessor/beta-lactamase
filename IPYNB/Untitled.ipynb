# %%
import os 
import pandas as pd

# %%
cd ..
# Out:
# /home/anindya/Documents/MachineLearning/beta-lactamase

# %%
base_path = os.path.join(os.getcwd(), 'Data')

# %%
train_data = pd.read_csv(os.path.join(base_path, 'train_data.csv'))

# %%
train_data.head()
# Out:
#    Unnamed: 0 molecule_chembl_id  standard_value  \
# 0           0         CHEMBL1018           316.2
# 1           1         CHEMBL1024         11220.2
# 2           2         CHEMBL1028          2818.4
# 3           3         CHEMBL1036            39.8
# 4           4         CHEMBL1054         15848.9
#
#                               canonical_smiles standard_relation  \
# 0       C/C=C(C(=C/C)/c1ccc(O)cc1)\c1ccc(O)cc1                 =
# 1                        O=P1(NCCCl)OCCCN1CCCl                 =
# 2                       CCNCC(=O)Nc1c(C)cccc1C                 =
# 3  OC(CCCN1CCC(O)(c2ccc(Cl)cc2)CC1)c1ccc(F)cc1                 =
# 4  NS(=O)(=O)c1cc2c(cc1Cl)NC(C(Cl)Cl)NS2(=O)=O                 =
#
#   standard_units standard_type  pchembl_value     target_pref_name  \
# 0             nM       Potency           6.50  Beta-lactamase AmpC
# 1             nM       Potency           4.95  Beta-lactamase AmpC
# 2             nM       Potency           5.55  Beta-lactamase AmpC
# ...

# %%
from rdkit import Chem

# %%
import deepchem as dc
# Out:
# 2022-02-25 11:56:46.066021: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-25 11:56:46.066064: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from tqdm.notebook import tqdm
data = train_data

# %%
featurizer = dc.feat.MolGraphConvFeaturizer(use_edges=True)

# %%
for _, row_data in tqdm(data.iterrows(), total=data.shape[0]):
    smiles = row_data['canonical_smiles']
    f = featurizer.featurizer(smiles)
    graph_data = f[0].to_pyg_graph()
    graph_data.y = float(row_data['pchembl_value'])
    graph_data.smiles = smiles
    
    atom_types =
# Out:
# C/C=C(C(=C/C)/c1ccc(O)cc1)\c1ccc(O)cc1
# O=P1(NCCCl)OCCCN1CCCl
# CCNCC(=O)Nc1c(C)cccc1C
# OC(CCCN1CCC(O)(c2ccc(Cl)cc2)CC1)c1ccc(F)cc1
# NS(=O)(=O)c1cc2c(cc1Cl)NC(C(Cl)Cl)NS2(=O)=O
# CN1C(=O)CCC1(O)c1ccccc1
# CCC(C)(C)C(=O)O[C@H]1C[C@@H](C)C=C2C=C[C@H](C)[C@H](CC[C@@H]3C[C@@H](O)CC(=O)O3)[C@H]21
# COc1cc2c(c(OC)c1OC)-c1ccc(OC)c(=O)cc1[C@@H](NC(C)=O)CC2
# Cc1cnc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)cc2)cn1
# Oc1ccc(Nc2nc(-c3ccc4ccccc4c3)cs2)cc1
# CCc1ccc(S(=O)(=O)c2nnn3c2nc(N2CCC(C)CC2)c2cc(Cl)ccc23)cc1
# Cc1cc(N2CCN(C)CC2)n2nc(-c3ccc(Cl)cc3)nc2n1
# COc1ccc(C(=O)OCCc2ccc(O)cc2)cc1
# Cc1ccc(Nc2nc3c(S(=O)(=O)c4ccccc4)nnn3c3ccc(Cl)cc23)c(C)c1
# CC(O)CCc1ccc(O)cc1
# COCCCNc1nc2c(S(=O)(=O)c3ccc(C)c(C)c3)nnn2c2ccc(Cl)cc12
# CC1CCN(c2nc3c(S(=O)(=O)c4ccccc4)nnn3c3ccc(Cl)cc23)CC1
# Cn1c(=O)c2c(-c3ccccc3)n3c(c2n(C)c1=O)C(c1cccc([N+](=O)[O-])c1)Nc1ccccc1-3
# CCOC(=O)C1CCCN(c2nc3c(S(=O)(=O)c4ccc(CC)cc4)nnn3c3ccc(Cl)cc23)C1
# CCN(CC)c1nc2c(S(=O)(=O)c3ccccc3)nnn2c2ccc(Cl)cc12
# ...
